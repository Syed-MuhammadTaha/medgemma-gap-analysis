# %% [markdown]
# # MedGemma on pathology patches

# %%
import os, shutil
from google.colab import files

# same layout as the repo: src/01_prepare_data.py reads ../data/
os.makedirs("data", exist_ok=True)
os.makedirs("src", exist_ok=True)
shutil.move("00_cases.csv", "data/00_cases.csv")
shutil.move("01_prepare_data.py", "src/01_prepare_data.py")

# %% [markdown]
# ## 1. Just downloading daata of fast Colab servers

# %%
# !pip install -q openslide-python openslide-bin
# !python src/01_prepare_data.py

# %%
# Colab files disappear when the session ends: keep a copy
# !zip -qr patches.zip data/patches
files.download("patches.zip")
